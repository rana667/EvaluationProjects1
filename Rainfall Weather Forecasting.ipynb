# %%
# Import required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("weatherAUS.csv")

# %%
# Top 5 records
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
# Last 5 records
df.tail()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 8420       1024.6       1020.3       NaN       NaN     10.1     22.4
# 8421       1023.5       1019.1       NaN       NaN     10.9     24.5
# 8422       1021.0       1016.8       NaN       NaN     12.5     26.1
# 8423       1019.4       1016.5       3.0       2.0     15.1     26.0
# 8424       1020.2       1017.9       8.0       8.0     15.0     20.9
#
#       RainToday  RainTomorrow
# 8420         No            No
# 8421         No            No
# 8422         No            No
# 8423         No            No
# 8424         No           NaN
#
# [5 rows x 23 columns]

# %%
print("Dataset have \nRows-",df.shape[0],'\nColumns -',df.shape[1])
# Out:
# Dataset have
# Rows- 8425
# Columns - 23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
#  17  Cloud9am       6004 non-null   float64
#  18  Cloud3pm       5970 non-null   float64
#  19  Temp9am        8369 non-null   float64
#  20  Temp3pm        8329 non-null   float64
#  21  RainToday      8185 non-null   object
#  22  RainTomorrow   8186 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 1.5+ MB

# %%
df.describe().T
# Out:
#                 count         mean        std    min      25%     50%     75%  \
# MinTemp        8350.0    13.193305   5.403596   -2.0     9.20    13.3    17.4
# MaxTemp        8365.0    23.859976   6.136408    8.2    19.30    23.3    28.0
# Rainfall       8185.0     2.805913  10.459379    0.0     0.00     0.0     1.0
# Evaporation    4913.0     5.389395   5.044484    0.0     2.60     4.6     7.0
# Sunshine       4431.0     7.632205   3.896235    0.0     4.75     8.7    10.7
# WindGustSpeed  7434.0    40.174469  14.665721    7.0    30.00    39.0    50.0
# WindSpeed9am   8349.0    13.847646  10.174579    0.0     6.00    13.0    20.0
# WindSpeed3pm   8318.0    18.533662   9.766986    0.0    11.00    19.0    24.0
# Humidity9am    8366.0    67.822496  16.833283   10.0    56.00    68.0    80.0
# Humidity3pm    8323.0    51.249790  18.423774    6.0    39.00    51.0    63.0
# Pressure9am    7116.0  1017.640233   6.828699  989.8  1013.00  1017.7  1022.3
# Pressure3pm    7113.0  1015.236075   6.766681  982.9  1010.40  1015.3  1019.8
# Cloud9am       6004.0     4.566622   2.877658    0.0     1.00     5.0     7.0
# Cloud3pm       5970.0     4.503183   2.731659    0.0     2.00     5.0     7.0
# Temp9am        8369.0    17.762015   5.627035    1.9    13.80    17.8    21.9
# Temp3pm        8329.0    22.442934   5.980020    7.3    18.00    21.9    26.4
#
#                   max
# MinTemp          28.5
# MaxTemp          45.5
# Rainfall        371.0
# Evaporation     145.0
# Sunshine         13.9
# WindGustSpeed   107.0
# WindSpeed9am     63.0
# WindSpeed3pm     83.0
# Humidity9am     100.0
# Humidity3pm      99.0
# Pressure9am    1039.0
# Pressure3pm    1036.0
# Cloud9am          8.0
# Cloud3pm          8.0
# Temp9am          39.4
# Temp3pm          44.1

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
round(df.isnull().sum()/df.shape[0]*100,2).sort_values(ascending=False)
# Out:
# Sunshine         47.41
# Evaporation      41.69
# Cloud3pm         29.14
# Cloud9am         28.74
# Pressure3pm      15.57
# Pressure9am      15.54
# WindGustDir      11.76
# WindGustSpeed    11.76
# WindDir9am        9.84
# WindDir3pm        3.66
# RainToday         2.85
# Rainfall          2.85
# RainTomorrow      2.84
# WindSpeed3pm      1.27
# Humidity3pm       1.21
# Temp3pm           1.14
# WindSpeed9am      0.90
# MinTemp           0.89
# MaxTemp           0.71
# Humidity9am       0.70
# Temp9am           0.66
# Location          0.00
# Date              0.00
# dtype: float64

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
catg_features=[col for col in df.columns if df[col].dtypes=='object']
cont_features=[col for col in df.columns if df[col].dtypes!='object']

# %%
catg_features
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
cont_features
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm']

# %%
plt.pie([len(catg_features),len(cont_features)],labels=['Categorical','Continuous'],textprops={'fontsize':12},autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22e176a9cf0>,
#   <matplotlib.patches.Wedge at 0x22e176a9c00>],
#  [Text(0.6343483909086429, 0.8986668564888858, 'Categorical'),
#   Text(-0.6343483909086428, -0.8986668564888859, 'Continuous')],
#  [Text(0.3460082132228961, 0.4901819217212104, '30.4%'),
#   Text(-0.34600821322289604, -0.49018192172121045, '69.6%')])

# %%
df['RainTomorrow'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['RainTomorrow'].value_counts(normalize=True,dropna=False)*100
# Out:
# No     73.531157
# Yes    23.632047
# NaN     2.836795
# Name: RainTomorrow, dtype: float64

# %%
target_df=df['RainTomorrow'].value_counts(normalize=True,dropna=False)*100

# %%
plt.figure(figsize=(8,6))
plt.title("Target Fetaure ( Rain Tomorrow) -Categories",fontweight='bold',fontsize=15)
ax=sns.barplot(x=target_df.index,y=target_df.values)
plt.xlabel('Rain Tomorrow')
plt.ylabel('Percentage')



for p in ax.patches:
    height=p.get_height()
    width=p.get_width()
    x,_=p.get_xy()
    ax.text(x +width/2.8,height+.5,f'{height:.2f}%')

# %%
df['Date'].nunique()
# Out:
# 3004

# %%
df['Location'].unique()
# Out:
# array(['Albury', 'CoffsHarbour', 'Newcastle', 'Penrith', 'Williamtown',
#        'Wollongong', 'Melbourne', 'Brisbane', 'Adelaide', 'PerthAirport',
#        'Darwin', 'Uluru'], dtype=object)

# %%
df['Location'].value_counts()
# Out:
# Melbourne       1622
# Williamtown     1230
# PerthAirport    1204
# Albury           907
# Newcastle        822
# CoffsHarbour     611
# Brisbane         579
# Penrith          482
# Wollongong       474
# Darwin           250
# Adelaide         205
# Uluru             39
# Name: Location, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['Location'],order=df['Location'].value_counts().index)
plt.xticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 plt.figure(figsize=(12,8))
# ----> 2 sns.countplot(df['Location'],order=df['Location'].value_counts().index)
#       3 plt.xticks(rotation=45)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:481, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     479 if order is not None:
#     480     error = "Input data must be a pandas object to reorder"
# --> 481     raise ValueError(error)
#     483 # The input data is an array
#     484 if hasattr(data, "shape"):
#
# ValueError: Input data must be a pandas object to reorder

# %%
sns.distplot(df['MinTemp'])
# Out:
# <Axes: xlabel='MinTemp', ylabel='Density'>

# %%
# Data distribution looke like normally distributed

# %%
sns.distplot(df['MaxTemp'])
# Out:
# <Axes: xlabel='MaxTemp', ylabel='Density'>

# %%
import random

color_=['#000057','#005757','#005700','#ad7100','#008080','#575757','#003153']
cmap_=['magma','copper','crest']

# %%
plt.figure(figsize=(16,50))
for i,col in enumerate(df[cont_features].columns):
    rand_col=color_[random.sample(range(6),1)[0]]
    plt.subplot(6,3,i+1)
    
    sns.kdeplot(data=df,x=col,color=rand_col,fill=rand_col,palette=cmap_[random.sample(range(3),1)[0]])

# %%
plt.figure(figsize=(16,50))
for i,col in enumerate(df[catg_features].columns):
    rand_col=color_[random.sample(range(6),1)[0]]
    plt.subplot(21,1,i+1)
    
    sns.countplot(data=df,x=col,color=rand_col,fill=rand_col,palette=cmap_[random.sample(range(3),1)[0]])

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.head(2)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
#
#    RainTomorrow
# 0            No
# 1            No
#
# [2 rows x 23 columns]

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['Location'],order=df['Location'].value_counts().index,hue=df['RainTomorrow'])
plt.xticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 plt.figure(figsize=(12,8))
# ----> 2 sns.countplot(df['Location'],order=df['Location'].value_counts().index,hue=df['RainTomorrow'])
#       3 plt.xticks(rotation=45)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:437, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     435 if hue is not None:
#     436     error = "Cannot use `hue` without `x` and `y`"
# --> 437     raise ValueError(error)
#     439 # No hue grouping with wide inputs
#     440 plot_hues = None
#
# ValueError: Cannot use `hue` without `x` and `y`

# %%
table=pd.crosstab(df['Location'],df['RainTomorrow'])
table.div(table.sum(1),axis=0).plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Location'>

# %%
sns.scatterplot(df['MinTemp'],df['MaxTemp'],hue='RainTomorrow',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sns.scatterplot(df['MinTemp'],df['MaxTemp'],hue='RainTomorrow',data=df)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
sns.scatterplot(df['Sunshine'],df['Evaporation'],hue='RainTomorrow',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 sns.scatterplot(df['Sunshine'],df['Evaporation'],hue='RainTomorrow',data=df)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
sns.scatterplot(df['WindGustSpeed'],df['WindGustDir'],hue='RainTomorrow',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 sns.scatterplot(df['WindGustSpeed'],df['WindGustDir'],hue='RainTomorrow',data=df)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
sns.scatterplot(df['WindSpeed9am'],df['WindDir9am'],hue='RainTomorrow',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sns.scatterplot(df['WindSpeed9am'],df['WindDir9am'],hue='RainTomorrow',data=df)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
sns.scatterplot(df['WindSpeed3pm'],df['WindDir3pm'],hue='RainTomorrow',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 sns.scatterplot(df['WindSpeed3pm'],df['WindDir3pm'],hue='RainTomorrow',data=df)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(df['Humidity3pm'],df['Humidity9am'],hue='RainTomorrow',size='Rainfall',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 plt.figure(figsize=(10,7))
# ----> 2 sns.scatterplot(df['Humidity3pm'],df['Humidity9am'],hue='RainTomorrow',size='Rainfall',data=df)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df['Pressure3pm'],df['Pressure9am'],hue='RainTomorrow',size='Rainfall',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 sns.scatterplot(df['Pressure3pm'],df['Pressure9am'],hue='RainTomorrow',size='Rainfall',data=df)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df['Cloud3pm'],df['Cloud9am'],hue='RainTomorrow',size='Rainfall',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 sns.scatterplot(df['Cloud3pm'],df['Cloud9am'],hue='RainTomorrow',size='Rainfall',data=df)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df['Temp3pm'],df['Temp9am'],hue='RainTomorrow',size='Rainfall',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 sns.scatterplot(df['Temp3pm'],df['Temp9am'],hue='RainTomorrow',size='Rainfall',data=df)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
df['RainToday'].value_counts()
# Out:
# No     6195
# Yes    1990
# Name: RainToday, dtype: int64

# %%
df.groupby('RainToday')['RainTomorrow'].value_counts()
# Out:
# RainToday  RainTomorrow
# No         No              5142
#            Yes              978
# Yes        No              1013
#            Yes              946
# Name: RainTomorrow, dtype: int64

# %%
sns.countplot(df['RainToday'],hue=df['RainTomorrow'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sns.countplot(df['RainToday'],hue=df['RainTomorrow'])
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:437, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     435 if hue is not None:
#     436     error = "Cannot use `hue` without `x` and `y`"
# --> 437     raise ValueError(error)
#     439 # No hue grouping with wide inputs
#     440 plot_hues = None
#
# ValueError: Cannot use `hue` without `x` and `y`

# %%
max_temp = df['MaxTemp']
min_temp = df['MinTemp']

min_temp.plot(figsize=(12,7), legend=True)
max_temp.plot(figsize=(12,7), color='r', legend=True)
plt.title('Maximum and Minimum Temperature across 2020 per day')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
#df['RainTomorrow'].replace('No',0,inplace=True)
#df['RainTomorrow'].replace('Yes',1,inplace=True)

# %%
#df['RainToday'].replace('No',0,inplace=True)
#df['RainToday'].replace('Yes',1,inplace=True)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
round(df.isnull().sum()/df.shape[0]*100,2).sort_values(ascending=False)
# Out:
# Sunshine         47.41
# Evaporation      41.69
# Cloud3pm         29.14
# Cloud9am         28.74
# Pressure3pm      15.57
# Pressure9am      15.54
# WindGustDir      11.76
# WindGustSpeed    11.76
# WindDir9am        9.84
# WindDir3pm        3.66
# RainToday         2.85
# Rainfall          2.85
# RainTomorrow      2.84
# WindSpeed3pm      1.27
# Humidity3pm       1.21
# Temp3pm           1.14
# WindSpeed9am      0.90
# MinTemp           0.89
# MaxTemp           0.71
# Humidity9am       0.70
# Temp9am           0.66
# Location          0.00
# Date              0.00
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
#  17  Cloud9am       6004 non-null   float64
#  18  Cloud3pm       5970 non-null   float64
#  19  Temp9am        8369 non-null   float64
#  20  Temp3pm        8329 non-null   float64
#  21  RainToday      8185 non-null   object
#  22  RainTomorrow   8186 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 1.5+ MB

# %%
# seprate database on basis of RainTomorrow

yes_rain = df[df['RainTomorrow']=='Yes']
no_rain = df[df['RainTomorrow']=='No']

# %%
yes_rain.shape , no_rain.shape
# Out:
# ((1991, 23), (6195, 23))

# %%
# For Temparatures replacing NaN with its respective mode value # Mode is most repeated values

# %%
yes_rain['MinTemp'].fillna(yes_rain['MinTemp'].mode()[0],inplace=True)
no_rain['MinTemp'].fillna(no_rain['MinTemp'].mode()[0],inplace=True)

yes_rain['MaxTemp'].fillna(yes_rain['MaxTemp'].mode()[0],inplace=True)
no_rain['MaxTemp'].fillna(no_rain['MaxTemp'].mode()[0],inplace=True)

yes_rain['Temp9am'].fillna(yes_rain['Temp9am'].mode()[0],inplace=True)
no_rain['Temp9am'].fillna(no_rain['Temp9am'].mode()[0],inplace=True)

yes_rain['Temp3pm'].fillna(yes_rain['Temp3pm'].mode()[0],inplace=True)
no_rain['Temp3pm'].fillna(no_rain['Temp3pm'].mode()[0],inplace=True)


yes_rain['Humidity3pm'].fillna(yes_rain['Humidity3pm'].mode()[0],inplace=True)
no_rain['Humidity3pm'].fillna(no_rain['Humidity3pm'].mode()[0],inplace=True)

yes_rain['Humidity9am'].fillna(yes_rain['Humidity9am'].mode()[0],inplace=True)
no_rain['Humidity9am'].fillna(no_rain['Humidity9am'].mode()[0],inplace=True)

# %%
round(df.isnull().sum()/df.shape[0]*100,2).sort_values(ascending=False)
# Out:
# Sunshine         47.41
# Evaporation      41.69
# Cloud3pm         29.14
# Cloud9am         28.74
# Pressure3pm      15.57
# Pressure9am      15.54
# WindGustDir      11.76
# WindGustSpeed    11.76
# WindDir9am        9.84
# WindDir3pm        3.66
# RainToday         2.85
# Rainfall          2.85
# RainTomorrow      2.84
# WindSpeed3pm      1.27
# Humidity3pm       1.21
# Temp3pm           1.14
# WindSpeed9am      0.90
# MinTemp           0.89
# MaxTemp           0.71
# Humidity9am       0.70
# Temp9am           0.66
# Location          0.00
# Date              0.00
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
#  17  Cloud9am       6004 non-null   float64
#  18  Cloud3pm       5970 non-null   float64
#  19  Temp9am        8369 non-null   float64
#  20  Temp3pm        8329 non-null   float64
#  21  RainToday      8185 non-null   object
#  22  RainTomorrow   8186 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 1.5+ MB

# %%
yes_rain['Sunshine'].fillna(yes_rain['Sunshine'].median(),inplace=True)
no_rain['Sunshine'].fillna(no_rain['Sunshine'].median(),inplace=True)

yes_rain['Evaporation'].fillna(yes_rain['Evaporation'].median(),inplace=True)
no_rain['Evaporation'].fillna(no_rain['Evaporation'].median(),inplace=True)

yes_rain['Cloud3pm'].fillna(yes_rain['Cloud3pm'].median(),inplace=True)
no_rain['Cloud3pm'].fillna(no_rain['Cloud3pm'].median(),inplace=True)

yes_rain['Cloud9am'].fillna(yes_rain['Cloud9am'].median(),inplace=True)
no_rain['Cloud9am'].fillna(no_rain['Cloud9am'].median(),inplace=True)

yes_rain['Pressure3pm'].fillna(yes_rain['Pressure3pm'].median(),inplace=True)
no_rain['Pressure3pm'].fillna(no_rain['Pressure3pm'].median(),inplace=True)

yes_rain['Pressure9am'].fillna(yes_rain['Pressure9am'].median(),inplace=True)
no_rain['Pressure9am'].fillna(no_rain['Pressure9am'].median(),inplace=True)

yes_rain['WindGustDir'].fillna(yes_rain['WindGustDir'].mode()[0],inplace=True)
no_rain['WindGustDir'].fillna(no_rain['WindGustDir'].mode()[0],inplace=True)

yes_rain['WindGustSpeed'].fillna(yes_rain['WindGustSpeed'].median(),inplace=True)
no_rain['WindGustSpeed'].fillna(no_rain['WindGustSpeed'].median(),inplace=True)

yes_rain['WindDir9am'].fillna(yes_rain['WindDir9am'].mode()[0],inplace=True)
no_rain['WindDir9am'].fillna(no_rain['WindDir9am'].mode()[0],inplace=True)

yes_rain['WindDir3pm'].fillna(yes_rain['WindDir3pm'].mode()[0],inplace=True)
no_rain['WindDir3pm'].fillna(no_rain['WindDir3pm'].mode()[0],inplace=True)

yes_rain['WindSpeed3pm'].fillna(yes_rain['WindSpeed3pm'].median(),inplace=True)
no_rain['WindSpeed3pm'].fillna(no_rain['WindSpeed3pm'].median(),inplace=True)

yes_rain['WindSpeed9am'].fillna(yes_rain['WindSpeed9am'].median(),inplace=True)
no_rain['WindSpeed9am'].fillna(no_rain['WindSpeed9am'].median(),inplace=True)



yes_rain['Rainfall'].fillna(yes_rain['Rainfall'].median(),inplace=True)
no_rain['Rainfall'].fillna(no_rain['Rainfall'].median(),inplace=True)

# %%
data= yes_rain.append(no_rain, ignore_index=True)

# %%
data
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-09   Albury      9.7     31.9       0.0          3.8       4.2
# 1     2008-12-11   Albury     13.4     30.4       0.0          3.8       4.2
# 2     2008-12-12   Albury     15.9     21.7       2.2          3.8       4.2
# 3     2008-12-13   Albury     15.9     18.6      15.6          3.8       4.2
# 4     2008-12-17   Albury     14.1     20.9       0.0          3.8       4.2
# ...          ...      ...      ...      ...       ...          ...       ...
# 8181  2017-06-20    Uluru      3.5     21.8       0.0          4.8       9.6
# 8182  2017-06-21    Uluru      2.8     23.4       0.0          4.8       9.6
# 8183  2017-06-22    Uluru      3.6     25.3       0.0          4.8       9.6
# 8184  2017-06-23    Uluru      5.4     26.9       0.0          4.8       9.6
# 8185  2017-06-24    Uluru      7.8     27.0       0.0          4.8       9.6
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0            NNW           80.0         SE  ...        42.0          9.0
# 1              N           30.0        SSE  ...        48.0         22.0
# 2            NNE           31.0         NE  ...        89.0         91.0
# 3              W           61.0        NNW  ...        76.0         93.0
# 4            ENE           22.0        SSW  ...        69.0         82.0
# ...          ...            ...        ...  ...         ...          ...
# 8181           E           31.0        ESE  ...        59.0         27.0
# 8182           E           31.0         SE  ...        51.0         24.0
# 8183         NNW           22.0         SE  ...        56.0         21.0
# 8184           N           37.0         SE  ...        53.0         24.0
# 8185          SE           28.0        SSE  ...        51.0         24.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0          1008.9       1003.6       7.0       7.0     18.3     30.2
# 1          1011.8       1008.7       7.0       7.0     20.4     28.8
# 2          1010.5       1004.2       8.0       8.0     15.9     17.0
# 3           994.3        993.0       8.0       8.0     17.4     15.8
# 4          1012.2       1010.4       8.0       1.0     17.2     18.1
# ...           ...          ...       ...       ...      ...      ...
# 8181       1024.7       1021.2       4.0       4.0      9.4     20.9
# 8182       1024.6       1020.3       4.0       4.0     10.1     22.4
# 8183       1023.5       1019.1       4.0       4.0     10.9     24.5
# 8184       1021.0       1016.8       4.0       4.0     12.5     26.1
# 8185       1019.4       1016.5       3.0       2.0     15.1     26.0
#
#       RainToday  RainTomorrow
# 0            No           Yes
# 1            No           Yes
# 2           Yes           Yes
# 3           Yes           Yes
# 4            No           Yes
# ...         ...           ...
# 8181         No            No
# 8182         No            No
# 8183         No            No
# 8184         No            No
# 8185         No            No
#
# [8186 rows x 23 columns]

# %%
data.shape
# Out:
# (8186, 23)

# %%
data.dropna(inplace=True)

# %%
#data['RainTomorrow'].replace('No',0,inplace=True)
#data['RainTomorrow'].replace('Yes',1,inplace=True)

#data['RainToday'].replace('No',0,inplace=True)
#data['RainToday'].replace('Yes',1,inplace=True)

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-09   Albury      9.7     31.9       0.0          3.8       4.2
# 1  2008-12-11   Albury     13.4     30.4       0.0          3.8       4.2
# 2  2008-12-12   Albury     15.9     21.7       2.2          3.8       4.2
# 3  2008-12-13   Albury     15.9     18.6      15.6          3.8       4.2
# 4  2008-12-17   Albury     14.1     20.9       0.0          3.8       4.2
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0         NNW           80.0         SE  ...        42.0          9.0
# 1           N           30.0        SSE  ...        48.0         22.0
# 2         NNE           31.0         NE  ...        89.0         91.0
# 3           W           61.0        NNW  ...        76.0         93.0
# 4         ENE           22.0        SSW  ...        69.0         82.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1008.9       1003.6       7.0       7.0     18.3     30.2         No
# 1       1011.8       1008.7       7.0       7.0     20.4     28.8         No
# 2       1010.5       1004.2       8.0       8.0     15.9     17.0        Yes
# 3        994.3        993.0       8.0       8.0     17.4     15.8        Yes
# 4       1012.2       1010.4       8.0       1.0     17.2     18.1         No
#
#    RainTomorrow
# 0           Yes
# 1           Yes
# 2           Yes
# 3           Yes
# 4           Yes
#
# [5 rows x 23 columns]

# %%
# COnvert Date feature into datetime
data['Date']=pd.to_datetime(data['Date'])

# %%
data['year']=data['Date'].dt.year

# %%
data['month']=data['Date'].dt.month

# %%
data['day']=data['Date'].dt.day

# %%
data.drop('Date',axis=1,inplace=True)

# %%
data
# Out:
#      Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      Albury      9.7     31.9       0.0          3.8       4.2         NNW
# 1      Albury     13.4     30.4       0.0          3.8       4.2           N
# 2      Albury     15.9     21.7       2.2          3.8       4.2         NNE
# 3      Albury     15.9     18.6      15.6          3.8       4.2           W
# 4      Albury     14.1     20.9       0.0          3.8       4.2         ENE
# ...       ...      ...      ...       ...          ...       ...         ...
# 8181    Uluru      3.5     21.8       0.0          4.8       9.6           E
# 8182    Uluru      2.8     23.4       0.0          4.8       9.6           E
# 8183    Uluru      3.6     25.3       0.0          4.8       9.6         NNW
# 8184    Uluru      5.4     26.9       0.0          4.8       9.6           N
# 8185    Uluru      7.8     27.0       0.0          4.8       9.6          SE
#
#       WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0              80.0         SE         NW  ...       1003.6       7.0
# 1              30.0        SSE        ESE  ...       1008.7       7.0
# 2              31.0         NE        ENE  ...       1004.2       8.0
# 3              61.0        NNW        NNW  ...        993.0       8.0
# 4              22.0        SSW          E  ...       1010.4       8.0
# ...             ...        ...        ...  ...          ...       ...
# 8181           31.0        ESE          E  ...       1021.2       4.0
# 8182           31.0         SE        ENE  ...       1020.3       4.0
# 8183           22.0         SE          N  ...       1019.1       4.0
# 8184           37.0         SE        WNW  ...       1016.8       4.0
# 8185           28.0        SSE          N  ...       1016.5       3.0
#
#       Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  year  month  day
# 0          7.0     18.3     30.2         No           Yes  2008     12    9
# 1          7.0     20.4     28.8         No           Yes  2008     12   11
# 2          8.0     15.9     17.0        Yes           Yes  2008     12   12
# 3          8.0     17.4     15.8        Yes           Yes  2008     12   13
# 4          1.0     17.2     18.1         No           Yes  2008     12   17
# ...        ...      ...      ...        ...           ...   ...    ...  ...
# 8181       4.0      9.4     20.9         No            No  2017      6   20
# 8182       4.0     10.1     22.4         No            No  2017      6   21
# 8183       4.0     10.9     24.5         No            No  2017      6   22
# 8184       4.0     12.5     26.1         No            No  2017      6   23
# 8185       2.0     15.1     26.0         No            No  2017      6   24
#
# [8079 rows x 25 columns]

# %%
d1=data  # will be used for regression problem

# %%
num=[col for col in data.columns if data[col].dtypes!='O']
num
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'year',
#  'month',
#  'day']

# %%
v=data[num]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]

# %%
VIF
# Out:
#          features        vif
# 0         MinTemp   8.536558
# 1         MaxTemp  25.650652
# 2        Rainfall   1.131077
# 3     Evaporation   1.217936
# 4        Sunshine   2.137066
# 5   WindGustSpeed   2.353808
# 6    WindSpeed9am   2.030998
# 7    WindSpeed3pm   1.946039
# 8     Humidity9am   3.854017
# 9     Humidity3pm   5.579726
# 10    Pressure9am  18.164613
# 11    Pressure3pm  17.796774
# 12       Cloud9am   2.022755
# 13       Cloud3pm   1.969383
# 14        Temp9am  17.380827
# 15        Temp3pm  32.596027
# 16           year   1.112733
# 17          month   1.171960
# 18            day   1.003529

# %%
num.remove('Temp3pm')

# %%
num.remove('Temp3pm')
v=data[num]
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 num.remove('Temp3pm')
#       2 v=data[num]
#       3 from sklearn.preprocessing import StandardScaler
#
# ValueError: list.remove(x): x not in list

# %%
num.remove('Pressure9am')

# %%
v=data[num]
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
#          features        vif
# 0         MinTemp   8.282180
# 1         MaxTemp   8.650329
# 2        Rainfall   1.124425
# 3     Evaporation   1.216592
# 4        Sunshine   2.134751
# 5   WindGustSpeed   2.325879
# 6    WindSpeed9am   2.025740
# 7    WindSpeed3pm   1.930832
# 8     Humidity9am   3.374529
# 9     Humidity3pm   3.783076
# 10    Pressure3pm   1.439756
# 11       Cloud9am   2.020075
# 12       Cloud3pm   1.956756
# 13        Temp9am  16.107884
# 14           year   1.112348
# 15          month   1.155157
# 16            day   1.002241

# %%
num.remove('Temp9am')

# %%
v=data[num]
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
#          features       vif
# 0         MinTemp  4.222621
# 1         MaxTemp  4.951979
# 2        Rainfall  1.121856
# 3     Evaporation  1.215636
# 4        Sunshine  2.131929
# 5   WindGustSpeed  2.291850
# 6    WindSpeed9am  2.006285
# 7    WindSpeed3pm  1.879912
# 8     Humidity9am  2.349810
# 9     Humidity3pm  2.972785
# 10    Pressure3pm  1.433960
# 11       Cloud9am  1.995461
# 12       Cloud3pm  1.952044
# 13           year  1.085107
# 14          month  1.142017
# 15            day  1.002009

# %%
data.shape
# Out:
# (8079, 25)

# %%
data.drop(['Temp3pm','Temp9am','Pressure9am'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (8079, 22)

# %%
data.head(2)
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury      9.7     31.9       0.0          3.8       4.2         NNW
# 1   Albury     13.4     30.4       0.0          3.8       4.2           N
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0           80.0         SE         NW  ...         42.0          9.0
# 1           30.0        SSE        ESE  ...         48.0         22.0
#
#    Pressure3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow  year month  day
# 0       1003.6       7.0       7.0         No           Yes  2008    12    9
# 1       1008.7       7.0       7.0         No           Yes  2008    12   11
#
# [2 rows x 22 columns]

# %%
for i in num:
    sns.boxplot(data[i])
    plt.show()

# %%
sns.distplot(data['Rainfall'])
# Out:
# <Axes: xlabel='Rainfall', ylabel='Density'>

# %%
data[num].skew()
# Out:
# MinTemp          -0.070098
# MaxTemp           0.394841
# Rainfall         13.073756
# Evaporation      13.998671
# Sunshine         -0.822526
# WindGustSpeed     0.784800
# WindSpeed9am      0.949237
# WindSpeed3pm      0.509973
# Humidity9am      -0.250378
# Humidity3pm       0.118933
# Pressure3pm      -0.011625
# Cloud9am         -0.261462
# Cloud3pm         -0.185359
# year              0.421639
# month             0.054225
# day               0.000577
# dtype: float64

# %%
for i in num:
    IQR= data[i].quantile(.75)-data[i].quantile(.25)
    lower=data[i].quantile(.25) - (1.5 * IQR)
    upper=data[i].quantile(.75) + (1.5 * IQR)
    data[i]=np.where(data[i]<lower,lower,data[i])
    data[i]=np.where(data[i]>upper,upper,data[i])

# %%
for i in num:
    sns.boxplot(data[i])
    plt.show()

# %%
data[num].skew()
# Out:
# MinTemp         -0.070098
# MaxTemp          0.372256
# Rainfall         1.226519
# Evaporation      0.042898
# Sunshine        -0.822526
# WindGustSpeed    0.556656
# WindSpeed9am     0.743355
# WindSpeed3pm     0.347722
# Humidity9am     -0.235208
# Humidity3pm      0.118933
# Pressure3pm      0.015165
# Cloud9am        -0.261462
# Cloud3pm        -0.185359
# year             0.421639
# month            0.054225
# day              0.000577
# dtype: float64

# %%
# Skewness has been handled

# %%
from sklearn.preprocessing import power_transform
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
for i in num:
    trans=power_transform(data[num])
    data[i]=sc.fit_transform(trans)

# %%
data.head()
# Out:
#   Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury -0.630013 -0.642992 -0.642992    -0.642992 -0.642992         NNW
# 1   Albury  0.054150  0.031187  0.031187     0.031187  0.031187           N
# 2   Albury  0.513327  0.498052  0.498052     0.498052  0.498052         NNE
# 3   Albury  0.513327  0.498052  0.498052     0.498052  0.498052           W
# 4   Albury  0.182945  0.161018  0.161018     0.161018  0.161018         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0      -0.642992         SE         NW  ...    -0.642992    -0.642992
# 1       0.031187        SSE        ESE  ...     0.031187     0.031187
# 2       0.498052         NE        ENE  ...     0.498052     0.498052
# 3       0.498052        NNW        NNW  ...     0.498052     0.498052
# 4       0.161018        SSW          E  ...     0.161018     0.161018
#
#    Pressure3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow      year  \
# 0    -0.642992 -0.642992 -0.642992         No           Yes -0.642992
# 1     0.031187  0.031187  0.031187         No           Yes  0.031187
# 2     0.498052  0.498052  0.498052        Yes           Yes  0.498052
# 3     0.498052  0.498052  0.498052        Yes           Yes  0.498052
# 4     0.161018  0.161018  0.161018         No           Yes  0.161018
#
#       month       day
# 0 -0.642992 -0.642992
# 1  0.031187  0.031187
# 2  0.498052  0.498052
# 3  0.498052  0.498052
# 4  0.161018  0.161018
#
# [5 rows x 22 columns]

# %%
data.head()
# Out:
#   Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury -0.630013 -0.642992 -0.642992    -0.642992 -0.642992         NNW
# 1   Albury  0.054150  0.031187  0.031187     0.031187  0.031187           N
# 2   Albury  0.513327  0.498052  0.498052     0.498052  0.498052         NNE
# 3   Albury  0.513327  0.498052  0.498052     0.498052  0.498052           W
# 4   Albury  0.182945  0.161018  0.161018     0.161018  0.161018         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0      -0.642992         SE         NW  ...    -0.642992    -0.642992
# 1       0.031187        SSE        ESE  ...     0.031187     0.031187
# 2       0.498052         NE        ENE  ...     0.498052     0.498052
# 3       0.498052        NNW        NNW  ...     0.498052     0.498052
# 4       0.161018        SSW          E  ...     0.161018     0.161018
#
#    Pressure3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow      year  \
# 0    -0.642992 -0.642992 -0.642992         No           Yes -0.642992
# 1     0.031187  0.031187  0.031187         No           Yes  0.031187
# 2     0.498052  0.498052  0.498052        Yes           Yes  0.498052
# 3     0.498052  0.498052  0.498052        Yes           Yes  0.498052
# 4     0.161018  0.161018  0.161018         No           Yes  0.161018
#
#       month       day
# 0 -0.642992 -0.642992
# 1  0.031187  0.031187
# 2  0.498052  0.498052
# 3  0.498052  0.498052
# 4  0.161018  0.161018
#
# [5 rows x 22 columns]

# %%
chitest=data[['Location','WindGustDir','WindDir9am','WindDir3pm','RainTomorrow']]
chitest
# Out:
#      Location WindGustDir WindDir9am WindDir3pm RainTomorrow
# 0      Albury         NNW         SE         NW          Yes
# 1      Albury           N        SSE        ESE          Yes
# 2      Albury         NNE         NE        ENE          Yes
# 3      Albury           W        NNW        NNW          Yes
# 4      Albury         ENE        SSW          E          Yes
# ...       ...         ...        ...        ...          ...
# 8181    Uluru           E        ESE          E           No
# 8182    Uluru           E         SE        ENE           No
# 8183    Uluru         NNW         SE          N           No
# 8184    Uluru           N         SE        WNW           No
# 8185    Uluru          SE        SSE          N           No
#
# [8079 rows x 5 columns]

# %%
import numpy as np
### let's perform label encoding on WindGustDir
ordinal_label = {k: i for i, k in enumerate(chitest['WindGustDir'].unique(), 0)}
chitest['WindGustDir'] = chitest['WindGustDir'].map(ordinal_label)

# %%
ordinal_label = {k: i for i, k in enumerate(chitest['Location'].unique(), 0)}
chitest['Location'] = chitest['Location'].map(ordinal_label)

# %%
ordinal_label = {k: i for i, k in enumerate(chitest['WindDir9am'].unique(), 0)}
chitest['WindDir9am'] = chitest['WindDir9am'].map(ordinal_label)

# %%
ordinal_label = {k: i for i, k in enumerate(chitest['WindDir3pm'].unique(), 0)}
chitest['WindDir3pm'] = chitest['WindDir3pm'].map(ordinal_label)

# %%
chitest['RainTomorrow'].replace('No',0,inplace=True)
chitest['RainTomorrow'].replace('Yes',1,inplace=True)

# %%
chitest
# Out:
#       Location  WindGustDir  WindDir9am  WindDir3pm  RainTomorrow
# 0            0            0           0           0             1
# 1            0            1           1           1             1
# 2            0            2           2           2             1
# 3            0            3           3           3             1
# 4            0            4           4           4             1
# ...        ...          ...         ...         ...           ...
# 8181        11           12           7           4             0
# 8182        11           12           0           2             0
# 8183        11            0           0           9             0
# 8184        11            1           0           5             0
# 8185        11            7           1           9             0
#
# [8079 rows x 5 columns]

# %%
inp=chitest.drop('RainTomorrow',axis=1)
out=chitest['RainTomorrow']

# %%
## Perform chi2 test
### chi2 returns 2 values
### Fscore and the pvalue
from sklearn.feature_selection import chi2
f_p_values=chi2(inp,out)

# %%
f_p_values
# Out:
# (array([34.02791176,  2.63753342, 20.16354411,  0.47166443]),
#  array([5.43271338e-09, 1.04365465e-01, 7.10950475e-06, 4.92222447e-01]))

# %%
p_values=pd.Series(f_p_values[1])
p_values.index=inp.columns
p_values
# Out:
# Location       5.432713e-09
# WindGustDir    1.043655e-01
# WindDir9am     7.109505e-06
# WindDir3pm     4.922224e-01
# dtype: float64

# %%
p_values.plot.bar()
# Out:
# <Axes: >

# %%
16-1 * (2-1 )
# Out:
# 15

# %%
data.drop('WindDir3pm',axis=1)
# Out:
#      Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      Albury -0.630013 -0.642992 -0.642992    -0.642992 -0.642992
# 1      Albury  0.054150  0.031187  0.031187     0.031187  0.031187
# 2      Albury  0.513327  0.498052  0.498052     0.498052  0.498052
# 3      Albury  0.513327  0.498052  0.498052     0.498052  0.498052
# 4      Albury  0.182945  0.161018  0.161018     0.161018  0.161018
# ...       ...       ...       ...       ...          ...       ...
# 8181    Uluru -1.794801 -1.751381 -1.751381    -1.751381 -1.751381
# 8182    Uluru -1.928608 -1.876512 -1.876512    -1.876512 -1.876512
# 8183    Uluru -1.775739 -1.733525 -1.733525    -1.733525 -1.733525
# 8184    Uluru -1.434531 -1.412489 -1.412489    -1.412489 -1.412489
# 8185    Uluru -0.983996 -0.984025 -0.984025    -0.984025 -0.984025
#
#      WindGustDir  WindGustSpeed WindDir9am  WindSpeed9am  ...  Humidity9am  \
# 0            NNW      -0.642992         SE     -0.642992  ...    -0.642992
# 1              N       0.031187        SSE      0.031187  ...     0.031187
# 2            NNE       0.498052         NE      0.498052  ...     0.498052
# 3              W       0.498052        NNW      0.498052  ...     0.498052
# 4            ENE       0.161018        SSW      0.161018  ...     0.161018
# ...          ...            ...        ...           ...  ...          ...
# 8181           E      -1.751381        ESE     -1.751381  ...    -1.751381
# 8182           E      -1.876512         SE     -1.876512  ...    -1.876512
# 8183         NNW      -1.733525         SE     -1.733525  ...    -1.733525
# 8184           N      -1.412489         SE     -1.412489  ...    -1.412489
# 8185          SE      -0.984025        SSE     -0.984025  ...    -0.984025
#
#       Humidity3pm  Pressure3pm  Cloud9am  Cloud3pm  RainToday RainTomorrow  \
# 0       -0.642992    -0.642992 -0.642992 -0.642992         No          Yes
# 1        0.031187     0.031187  0.031187  0.031187         No          Yes
# 2        0.498052     0.498052  0.498052  0.498052        Yes          Yes
# 3        0.498052     0.498052  0.498052  0.498052        Yes          Yes
# 4        0.161018     0.161018  0.161018  0.161018         No          Yes
# ...           ...          ...       ...       ...        ...          ...
# 8181    -1.751381    -1.751381 -1.751381 -1.751381         No           No
# 8182    -1.876512    -1.876512 -1.876512 -1.876512         No           No
# 8183    -1.733525    -1.733525 -1.733525 -1.733525         No           No
# 8184    -1.412489    -1.412489 -1.412489 -1.412489         No           No
# 8185    -0.984025    -0.984025 -0.984025 -0.984025         No           No
#
#           year     month       day
# 0    -0.642992 -0.642992 -0.642992
# 1     0.031187  0.031187  0.031187
# 2     0.498052  0.498052  0.498052
# 3     0.498052  0.498052  0.498052
# 4     0.161018  0.161018  0.161018
# ...        ...       ...       ...
# 8181 -1.751381 -1.751381 -1.751381
# 8182 -1.876512 -1.876512 -1.876512
# 8183 -1.733525 -1.733525 -1.733525
# 8184 -1.412489 -1.412489 -1.412489
# 8185 -0.984025 -0.984025 -0.984025
#
# [8079 rows x 21 columns]

# %%
data['RainTomorrow'].replace('No',0,inplace=True)
data['RainTomorrow'].replace('Yes',1,inplace=True)

data['RainToday'].replace('No',0,inplace=True)
data['RainToday'].replace('Yes',1,inplace=True)

# %%
data.head()
# Out:
#   Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury -0.630013 -0.642992 -0.642992    -0.642992 -0.642992         NNW
# 1   Albury  0.054150  0.031187  0.031187     0.031187  0.031187           N
# 2   Albury  0.513327  0.498052  0.498052     0.498052  0.498052         NNE
# 3   Albury  0.513327  0.498052  0.498052     0.498052  0.498052           W
# 4   Albury  0.182945  0.161018  0.161018     0.161018  0.161018         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0      -0.642992         SE         NW  ...    -0.642992    -0.642992
# 1       0.031187        SSE        ESE  ...     0.031187     0.031187
# 2       0.498052         NE        ENE  ...     0.498052     0.498052
# 3       0.498052        NNW        NNW  ...     0.498052     0.498052
# 4       0.161018        SSW          E  ...     0.161018     0.161018
#
#    Pressure3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow      year  \
# 0    -0.642992 -0.642992 -0.642992          0             1 -0.642992
# 1     0.031187  0.031187  0.031187          0             1  0.031187
# 2     0.498052  0.498052  0.498052          1             1  0.498052
# 3     0.498052  0.498052  0.498052          1             1  0.498052
# 4     0.161018  0.161018  0.161018          0             1  0.161018
#
#       month       day
# 0 -0.642992 -0.642992
# 1  0.031187  0.031187
# 2  0.498052  0.498052
# 3  0.498052  0.498052
# 4  0.161018  0.161018
#
# [5 rows x 22 columns]

# %%
X=data.drop('RainTomorrow',axis=1)
Y=data['RainTomorrow']

# %%
X.shape  , Y.shape
# Out:
# ((8079, 21), (8079,))

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
X.shape , Y.shape
# Out:
# ((8079, 73), (8079,))

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(X,Y)

# %%
x.shape , y.shape
# Out:
# ((12310, 73), (12310,))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score

# %%
# FInd best Random_state

maxaccu=0
maxRS=0

for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=i,test_size=.30)
    LR= LogisticRegression()
    LR.fit(x_train,y_train)
    pred= LR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxRS=i
print("Best accuracy is ",maxaccu,"on Random State =",maxRS)
# Out:
# Best accuracy is  0.7733549959382616 on Random State = 183

# %%
# Use, Random state= 122

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=122,test_size=.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[126], line 7
#       5 from sklearn.neighbors import KNeighborsClassifier
#       6 from sklearn.ensemble import RandomForestClassifier
# ----> 7 from xgboost import XGBClassifier
#       8 from sklearn.linear_model import SGDClassifier
#       9 from sklearn.ensemble import BaggingClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
LR_model= LogisticRegression()
RD_model= RidgeClassifier()
DT_model= DecisionTreeClassifier()
SV_model= SVC()
KNR_model= KNeighborsClassifier()
RFR_model= RandomForestClassifier()
XGB_model= XGBClassifier()
SGH_model= SGDClassifier()
Bag_model=BaggingClassifier()
ADA_model=AdaBoostClassifier()
GB_model= GradientBoostingClassifier()

model=[LR_model,RD_model,DT_model,SV_model,KNR_model,RFR_model,XGB_model,SGH_model,Bag_model,ADA_model,GB_model ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[127], line 7
#       5 KNR_model= KNeighborsClassifier()
#       6 RFR_model= RandomForestClassifier()
# ----> 7 XGB_model= XGBClassifier()
#       8 SGH_model= SGDClassifier()
#       9 Bag_model=BaggingClassifier()
#
# NameError: name 'XGBClassifier' is not defined

# %%
accuracy=[]
f1=[]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred= m.predict(x_test)
    accuracy.append(round(accuracy_score(y_test,pred) * 100, 2))
    f1.append(round(f1_score(y_test,pred) * 100, 2))
    #print('Accuracy_Score of ',m, 'is', accuracy_score(y_test,pred)*100)
    #print("F1 SCore                ", f1_score(y_test,pred)*100)
    #print('Confusion Matrix of ',m,' is \n', confusion_matrix(y_test,pred) )
    #print(classification_report(y_test,pred))
    #print('*'*50)
    
pd.DataFrame({'Model':model,'Accuracy':accuracy,'F1 Score':f1})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[128], line 4
#       1 accuracy=[]
#       2 f1=[]
# ----> 4 for m in model:
#       5     m.fit(x_train,y_train)
#       6     m.score(x_train,y_train)
#
# NameError: name 'model' is not defined

# %%
params = {'n_estimators' : [100,150,200,300,500],
    'max_features' : [1, 2, 3, 4, 5],
    'max_samples' : [0.05, 0.1, 0.2, 0.5]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
GCV=GridSearchCV(Bag_model,param_grid=params,cv=5,n_jobs=-1,verbose=2)
GCV.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 GCV=GridSearchCV(Bag_model,param_grid=params,cv=5,n_jobs=-1,verbose=2)
#       2 GCV.fit(x_train,y_train)
#
# NameError: name 'Bag_model' is not defined

# %%
GCV.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 GCV.best_estimator_
#
# NameError: name 'GCV' is not defined

# %%
GCV.best_params_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 GCV.best_params_
#
# NameError: name 'GCV' is not defined

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)
accuracy_score(y_test,GCV_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 GCV_pred=GCV.best_estimator_.predict(x_test)
#       2 accuracy_score(y_test,GCV_pred)
#
# NameError: name 'GCV' is not defined

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
sns.heatmap(confusion_matrix(y_test,pred),annot=True, fmt='d')
# Out:
# <Axes: >

# %%
from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve
#
# ImportError: cannot import name 'plot_roc_curve' from 'sklearn.metrics' (C:\Users\Abhimanyu Singh\anaconda3\lib\site-packages\sklearn\metrics\__init__.py)

# %%
from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve
plot_roc_curve(GB_model,x_test,y_test)
plt.title('ROC AUC Plot')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve
#       2 plot_roc_curve(GB_model,x_test,y_test)
#       3 plt.title('ROC AUC Plot')
#
# ImportError: cannot import name 'plot_roc_curve' from 'sklearn.metrics' (C:\Users\Abhimanyu Singh\anaconda3\lib\site-packages\sklearn\metrics\__init__.py)

# %%
import joblib
joblib.dump(GB_model,"Rainfall_Prediction.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[138], line 2
#       1 import joblib
# ----> 2 joblib.dump(GB_model,"Rainfall_Prediction.pkl")
#
# NameError: name 'GB_model' is not defined

# %%
d1.head()
# Out:
#   Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury -0.630013 -0.642992 -0.642992    -0.642992 -0.642992         NNW
# 1   Albury  0.054150  0.031187  0.031187     0.031187  0.031187           N
# 2   Albury  0.513327  0.498052  0.498052     0.498052  0.498052         NNE
# 3   Albury  0.513327  0.498052  0.498052     0.498052  0.498052           W
# 4   Albury  0.182945  0.161018  0.161018     0.161018  0.161018         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0      -0.642992         SE         NW  ...    -0.642992    -0.642992
# 1       0.031187        SSE        ESE  ...     0.031187     0.031187
# 2       0.498052         NE        ENE  ...     0.498052     0.498052
# 3       0.498052        NNW        NNW  ...     0.498052     0.498052
# 4       0.161018        SSW          E  ...     0.161018     0.161018
#
#    Pressure3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow      year  \
# 0    -0.642992 -0.642992 -0.642992          0             1 -0.642992
# 1     0.031187  0.031187  0.031187          0             1  0.031187
# 2     0.498052  0.498052  0.498052          1             1  0.498052
# 3     0.498052  0.498052  0.498052          1             1  0.498052
# 4     0.161018  0.161018  0.161018          0             1  0.161018
#
#       month       day
# 0 -0.642992 -0.642992
# 1  0.031187  0.031187
# 2  0.498052  0.498052
# 3  0.498052  0.498052
# 4  0.161018  0.161018
#
# [5 rows x 22 columns]

# %%
round(d1.isnull().sum()/d1.shape[0]*100,2).sort_values(ascending=False)
# Out:
# Location         0.0
# MinTemp          0.0
# month            0.0
# year             0.0
# RainTomorrow     0.0
# RainToday        0.0
# Cloud3pm         0.0
# Cloud9am         0.0
# Pressure3pm      0.0
# Humidity3pm      0.0
# Humidity9am      0.0
# WindSpeed3pm     0.0
# WindSpeed9am     0.0
# WindDir3pm       0.0
# WindDir9am       0.0
# WindGustSpeed    0.0
# WindGustDir      0.0
# Sunshine         0.0
# Evaporation      0.0
# Rainfall         0.0
# MaxTemp          0.0
# day              0.0
# dtype: float64

# %%
plt.figure(figsize=(15,8))
sns.heatmap(d1.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.heatmap(d1.corr(),annot=True)
# Out:
# <Axes: >

# %%
cont.remove('Rainfall')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 cont.remove('Rainfall')
#
# NameError: name 'cont' is not defined

# %%
cont
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 cont
#
# NameError: name 'cont' is not defined

# %%
v=d1[cont]
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 v=d1[cont]
#       2 from sklearn.preprocessing import StandardScaler
#       3 sc=StandardScaler()
#
# NameError: name 'cont' is not defined

# %%
cont.remove('MaxTemp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 cont.remove('MaxTemp')
#
# NameError: name 'cont' is not defined

# %%
v=d1[cont]
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 v=d1[cont]
#       2 from sklearn.preprocessing import StandardScaler
#       3 sc=StandardScaler()
#
# NameError: name 'cont' is not defined

# %%
cont.remove('Pressure9am')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 cont.remove('Pressure9am')
#
# NameError: name 'cont' is not defined

# %%
v=d1[cont]
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 v=d1[cont]
#       2 from sklearn.preprocessing import StandardScaler
#       3 sc=StandardScaler()
#
# NameError: name 'cont' is not defined

# %%
cont.remove('Temp9am')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 cont.remove('Temp9am')
#
# NameError: name 'cont' is not defined

# %%
v=d1[cont]
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(v)
VIF= pd.DataFrame()
VIF['features']=v.columns
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 v=d1[cont]
#       2 from sklearn.preprocessing import StandardScaler
#       3 sc=StandardScaler()
#
# NameError: name 'cont' is not defined

# %%
d1.drop(['Temp9am','Pressure9am','MaxTemp'],axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 d1.drop(['Temp9am','Pressure9am','MaxTemp'],axis=1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Temp9am', 'Pressure9am'] not found in axis"

# %%
d1.head()

# %%
Location	MinTemp	Rainfall	Evaporation	Sunshine	WindGustDir	WindGustSpeed	WindDir9am	WindDir3pm	WindSpeed9am	...	Humidity3pm	Pressure3pm	Cloud9am	Cloud3pm	Temp3pm	RainToday	RainTomorrow	year	month	day
0	Albury	9.7	0.0	3.8	4.2	NNW	80.0	SE	NW	7.0	...	9.0	1003.6	7.0	7.0	30.2	No	Yes	2008	12	9
1	Albury	13.4	0.0	3.8	4.2	N	30.0	SSE	ESE	17.0	...	22.0	1008.7	7.0	7.0	28.8	No	Yes	2008	12	11
2	Albury	15.9	2.2	3.8	4.2	NNE	31.0	NE	ENE	15.0	...	91.0	1004.2	8.0	8.0	17.0	Yes	Yes	2008	12	12
3	Albury	15.9	15.6	3.8	4.2	W	61.0	NNW	NNW	28.0	...	93.0	993.0	8.0	8.0	15.8	Yes	Yes	2008	12	13
4	Albury	14.1	0.0	3.8	4.2	ENE	22.0	SSW	E	11.0	...	82.0	1010.4	8.0	1.0	18.1	No	Yes	2008	12	17
5 rows × 22 columns

plt.figure(figsize=(15,8))
sns.heatmap(d1.corr(),annot=True)
# Out:
#   Cell In[153], line 7
#     5 rows × 22 columns
#            ^
# SyntaxError: invalid character '×' (U+00D7)

# %%
X=d1.drop('Rainfall',axis=1)
Y=d1['Rainfall']

# %%
X.shape , Y.shape
# Out:
# ((8079, 21), (8079,))

# %%
cont= [i for i in X.columns if X[i].dtypes!='O']

# %%
for i in cont:
    sns.boxplot(X[i])
    plt.show()

# %%
X[cont].skew()
# Out:
# MinTemp         -0.099928
# MaxTemp         -0.010778
# Evaporation     -0.010778
# Sunshine        -0.010778
# WindGustSpeed   -0.010778
# WindSpeed9am    -0.010778
# WindSpeed3pm    -0.010778
# Humidity9am     -0.010778
# Humidity3pm     -0.010778
# Pressure3pm     -0.010778
# Cloud9am        -0.010778
# Cloud3pm        -0.010778
# RainToday        1.201947
# RainTomorrow     1.229722
# year            -0.010778
# month           -0.010778
# day             -0.010778
# dtype: float64

# %%
for i in cont:
    IQR= X[i].quantile(.75)-X[i].quantile(.25)
    lower=X[i].quantile(.25) - (1.5 * IQR)
    upper=X[i].quantile(.75) + (1.5 * IQR)
    X[i]=np.where(X[i]<lower,lower,X[i])
    X[i]=np.where(X[i]>upper,upper,X[i])

# %%
X[cont].skew()
# Out:
# MinTemp         -0.099928
# MaxTemp         -0.010778
# Evaporation     -0.010778
# Sunshine        -0.010778
# WindGustSpeed   -0.010778
# WindSpeed9am    -0.010778
# WindSpeed3pm    -0.010778
# Humidity9am     -0.010778
# Humidity3pm     -0.010778
# Pressure3pm     -0.010778
# Cloud9am        -0.010778
# Cloud3pm        -0.010778
# RainToday        0.000000
# RainTomorrow     0.000000
# year            -0.010778
# month           -0.010778
# day             -0.010778
# dtype: float64

# %%
# Skewness removed after handling outliers

# %%
from sklearn.preprocessing import power_transform
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
for i in cont:
    trans=power_transform(data[cont])
    X[i]=sc.fit_transform(trans)

# %%
X.head()
# Out:
#   Location   MinTemp   MaxTemp  Evaporation  Sunshine WindGustDir  \
# 0   Albury -0.642992 -0.642992    -0.642992 -0.642992         NNW
# 1   Albury  0.031187  0.031187     0.031187  0.031187           N
# 2   Albury  0.498052  0.498052     0.498052  0.498052         NNE
# 3   Albury  0.498052  0.498052     0.498052  0.498052           W
# 4   Albury  0.161018  0.161018     0.161018  0.161018         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0      -0.642992         SE         NW     -0.642992  ...    -0.642992
# 1       0.031187        SSE        ESE      0.031187  ...     0.031187
# 2       0.498052         NE        ENE      0.498052  ...     0.498052
# 3       0.498052        NNW        NNW      0.498052  ...     0.498052
# 4       0.161018        SSW          E      0.161018  ...     0.161018
#
#    Humidity3pm  Pressure3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow  \
# 0    -0.642992    -0.642992 -0.642992 -0.642992  -0.642992     -0.642992
# 1     0.031187     0.031187  0.031187  0.031187   0.031187      0.031187
# 2     0.498052     0.498052  0.498052  0.498052   0.498052      0.498052
# 3     0.498052     0.498052  0.498052  0.498052   0.498052      0.498052
# 4     0.161018     0.161018  0.161018  0.161018   0.161018      0.161018
#
#        year     month       day
# 0 -0.642992 -0.642992 -0.642992
# 1  0.031187  0.031187  0.031187
# 2  0.498052  0.498052  0.498052
# 3  0.498052  0.498052  0.498052
# 4  0.161018  0.161018  0.161018
#
# [5 rows x 21 columns]

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
X.shape  , Y.shape
# Out:
# ((8079, 73), (8079,))

# %%
# Its a Regression problem coz output variable have continuous data, sales prediction
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

LR= LinearRegression()

# %%
# Train Test Split / finding best random_state for my model

for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(X,Y,random_state=i,test_size=.2)
    LR.fit(x_train,y_train)
    train_pred=LR.predict(x_train)
    test_pred=LR.predict(x_test)
    if round(r2_score(y_test,test_pred),2)==round(r2_score(y_train,train_pred),2):
        print("At random state ", i, "The model performance very well")
        print("At random state: ",i)
        print("Test R2 score is: ", round(r2_score(y_test,test_pred),2))
        print('Train R2 score is: ', round(r2_score(y_train,train_pred),2))
        print('X'*50,'\n')
# Out:
# At random state  0 The model performance very well
# At random state:  0
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  1 The model performance very well
# At random state:  1
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  2 The model performance very well
# At random state:  2
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  3 The model performance very well
# At random state:  3
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  4 The model performance very well
# At random state:  4
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  5 The model performance very well
# At random state:  5
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  6 The model performance very well
# At random state:  6
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  7 The model performance very well
# At random state:  7
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  8 The model performance very well
# At random state:  8
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  9 The model performance very well
# At random state:  9
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  10 The model performance very well
# At random state:  10
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  11 The model performance very well
# At random state:  11
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  12 The model performance very well
# At random state:  12
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  13 The model performance very well
# At random state:  13
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  14 The model performance very well
# At random state:  14
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  15 The model performance very well
# At random state:  15
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  16 The model performance very well
# At random state:  16
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  17 The model performance very well
# At random state:  17
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  18 The model performance very well
# At random state:  18
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  19 The model performance very well
# At random state:  19
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  20 The model performance very well
# At random state:  20
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  21 The model performance very well
# At random state:  21
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  22 The model performance very well
# At random state:  22
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  23 The model performance very well
# At random state:  23
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  24 The model performance very well
# At random state:  24
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  25 The model performance very well
# At random state:  25
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  26 The model performance very well
# At random state:  26
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  27 The model performance very well
# At random state:  27
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  28 The model performance very well
# At random state:  28
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  29 The model performance very well
# At random state:  29
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  30 The model performance very well
# At random state:  30
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  31 The model performance very well
# At random state:  31
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  32 The model performance very well
# At random state:  32
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  33 The model performance very well
# At random state:  33
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  34 The model performance very well
# At random state:  34
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  35 The model performance very well
# At random state:  35
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  36 The model performance very well
# At random state:  36
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  37 The model performance very well
# At random state:  37
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  38 The model performance very well
# At random state:  38
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  39 The model performance very well
# At random state:  39
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  40 The model performance very well
# At random state:  40
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  41 The model performance very well
# At random state:  41
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  42 The model performance very well
# At random state:  42
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  43 The model performance very well
# At random state:  43
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  44 The model performance very well
# At random state:  44
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  45 The model performance very well
# At random state:  45
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  46 The model performance very well
# At random state:  46
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  47 The model performance very well
# At random state:  47
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  48 The model performance very well
# At random state:  48
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  49 The model performance very well
# At random state:  49
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  50 The model performance very well
# At random state:  50
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  51 The model performance very well
# At random state:  51
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  52 The model performance very well
# At random state:  52
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  53 The model performance very well
# At random state:  53
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  54 The model performance very well
# At random state:  54
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  55 The model performance very well
# At random state:  55
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  56 The model performance very well
# At random state:  56
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  57 The model performance very well
# At random state:  57
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  58 The model performance very well
# At random state:  58
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  59 The model performance very well
# At random state:  59
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  60 The model performance very well
# At random state:  60
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  61 The model performance very well
# At random state:  61
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  62 The model performance very well
# At random state:  62
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  63 The model performance very well
# At random state:  63
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  64 The model performance very well
# At random state:  64
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  65 The model performance very well
# At random state:  65
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  66 The model performance very well
# At random state:  66
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  67 The model performance very well
# At random state:  67
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  68 The model performance very well
# At random state:  68
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  69 The model performance very well
# At random state:  69
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  70 The model performance very well
# At random state:  70
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  71 The model performance very well
# At random state:  71
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  72 The model performance very well
# At random state:  72
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  73 The model performance very well
# At random state:  73
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  74 The model performance very well
# At random state:  74
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  75 The model performance very well
# At random state:  75
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  76 The model performance very well
# At random state:  76
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  77 The model performance very well
# At random state:  77
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  78 The model performance very well
# At random state:  78
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  79 The model performance very well
# At random state:  79
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  80 The model performance very well
# At random state:  80
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  81 The model performance very well
# At random state:  81
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  82 The model performance very well
# At random state:  82
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  83 The model performance very well
# At random state:  83
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  84 The model performance very well
# At random state:  84
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  85 The model performance very well
# At random state:  85
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  86 The model performance very well
# At random state:  86
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  87 The model performance very well
# At random state:  87
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  88 The model performance very well
# At random state:  88
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  89 The model performance very well
# At random state:  89
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  90 The model performance very well
# At random state:  90
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  91 The model performance very well
# At random state:  91
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  92 The model performance very well
# At random state:  92
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  93 The model performance very well
# At random state:  93
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  94 The model performance very well
# At random state:  94
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  95 The model performance very well
# At random state:  95
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  96 The model performance very well
# At random state:  96
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  97 The model performance very well
# At random state:  97
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  98 The model performance very well
# At random state:  98
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  99 The model performance very well
# At random state:  99
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  100 The model performance very well
# At random state:  100
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  101 The model performance very well
# At random state:  101
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  102 The model performance very well
# At random state:  102
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  103 The model performance very well
# At random state:  103
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  104 The model performance very well
# At random state:  104
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  105 The model performance very well
# At random state:  105
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  106 The model performance very well
# At random state:  106
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  107 The model performance very well
# At random state:  107
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  108 The model performance very well
# At random state:  108
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  109 The model performance very well
# At random state:  109
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  110 The model performance very well
# At random state:  110
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  111 The model performance very well
# At random state:  111
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  112 The model performance very well
# At random state:  112
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  113 The model performance very well
# At random state:  113
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  114 The model performance very well
# At random state:  114
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  115 The model performance very well
# At random state:  115
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  116 The model performance very well
# At random state:  116
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  117 The model performance very well
# At random state:  117
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  118 The model performance very well
# At random state:  118
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  119 The model performance very well
# At random state:  119
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  120 The model performance very well
# At random state:  120
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  121 The model performance very well
# At random state:  121
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  122 The model performance very well
# At random state:  122
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  123 The model performance very well
# At random state:  123
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  124 The model performance very well
# At random state:  124
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  125 The model performance very well
# At random state:  125
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  126 The model performance very well
# At random state:  126
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  127 The model performance very well
# At random state:  127
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  128 The model performance very well
# At random state:  128
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  129 The model performance very well
# At random state:  129
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  130 The model performance very well
# At random state:  130
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  131 The model performance very well
# At random state:  131
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  132 The model performance very well
# At random state:  132
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  133 The model performance very well
# At random state:  133
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  134 The model performance very well
# At random state:  134
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  135 The model performance very well
# At random state:  135
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  136 The model performance very well
# At random state:  136
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  137 The model performance very well
# At random state:  137
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  138 The model performance very well
# At random state:  138
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  139 The model performance very well
# At random state:  139
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  140 The model performance very well
# At random state:  140
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  141 The model performance very well
# At random state:  141
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  142 The model performance very well
# At random state:  142
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  143 The model performance very well
# At random state:  143
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  144 The model performance very well
# At random state:  144
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  145 The model performance very well
# At random state:  145
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  146 The model performance very well
# At random state:  146
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  147 The model performance very well
# At random state:  147
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  148 The model performance very well
# At random state:  148
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  149 The model performance very well
# At random state:  149
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  150 The model performance very well
# At random state:  150
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  151 The model performance very well
# At random state:  151
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  152 The model performance very well
# At random state:  152
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  153 The model performance very well
# At random state:  153
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  154 The model performance very well
# At random state:  154
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  155 The model performance very well
# At random state:  155
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  156 The model performance very well
# At random state:  156
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  157 The model performance very well
# At random state:  157
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  158 The model performance very well
# At random state:  158
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  159 The model performance very well
# At random state:  159
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  160 The model performance very well
# At random state:  160
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  161 The model performance very well
# At random state:  161
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  162 The model performance very well
# At random state:  162
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  163 The model performance very well
# At random state:  163
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  164 The model performance very well
# At random state:  164
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  165 The model performance very well
# At random state:  165
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  166 The model performance very well
# At random state:  166
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  167 The model performance very well
# At random state:  167
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  168 The model performance very well
# At random state:  168
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  169 The model performance very well
# At random state:  169
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  170 The model performance very well
# At random state:  170
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  171 The model performance very well
# At random state:  171
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  172 The model performance very well
# At random state:  172
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  173 The model performance very well
# At random state:  173
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  174 The model performance very well
# At random state:  174
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  175 The model performance very well
# At random state:  175
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  176 The model performance very well
# At random state:  176
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  177 The model performance very well
# At random state:  177
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  178 The model performance very well
# At random state:  178
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  179 The model performance very well
# At random state:  179
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  180 The model performance very well
# At random state:  180
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  181 The model performance very well
# At random state:  181
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  182 The model performance very well
# At random state:  182
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  183 The model performance very well
# At random state:  183
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  184 The model performance very well
# At random state:  184
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  185 The model performance very well
# At random state:  185
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  186 The model performance very well
# At random state:  186
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  187 The model performance very well
# At random state:  187
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  188 The model performance very well
# At random state:  188
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  189 The model performance very well
# At random state:  189
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  190 The model performance very well
# At random state:  190
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  191 The model performance very well
# At random state:  191
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  192 The model performance very well
# At random state:  192
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  193 The model performance very well
# At random state:  193
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  194 The model performance very well
# At random state:  194
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  195 The model performance very well
# At random state:  195
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  196 The model performance very well
# At random state:  196
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  197 The model performance very well
# At random state:  197
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  198 The model performance very well
# At random state:  198
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  199 The model performance very well
# At random state:  199
# Test R2 score is:  1.0
# Train R2 score is:  1.0
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
# Select Random state= 23

x_train,x_test,y_train,y_test= train_test_split(X,Y,random_state=23,test_size=.3)
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[170], line 7
#       5 from sklearn.neighbors import KNeighborsRegressor
#       6 from sklearn.ensemble import RandomForestRegressor
# ----> 7 from xgboost import XGBRegressor
#       8 from sklearn.linear_model import ElasticNet
#       9 from sklearn.linear_model import SGDRegressor
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
LR_model= LinearRegression()
RD_model= Ridge()
LS_model= Lasso()
DT_model= DecisionTreeRegressor()
SV_model= SVR()
KNR_model= KNeighborsRegressor()
RFR_model= RandomForestRegressor()
XGB_model= XGBRegressor()
Elastic_model= ElasticNet()
SGH_model= SGDRegressor()
Bag_model=BaggingRegressor()
ADA_model=AdaBoostRegressor()
GB_model= GradientBoostingRegressor()

model=[LR_model,RD_model,LS_model,DT_model,SV_model,KNR_model,RFR_model,XGB_model,Elastic_model,SGH_model,Bag_model,ADA_model,GB_model ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[171], line 8
#       6 KNR_model= KNeighborsRegressor()
#       7 RFR_model= RandomForestRegressor()
# ----> 8 XGB_model= XGBRegressor()
#       9 Elastic_model= ElasticNet()
#      10 SGH_model= SGDRegressor()
#
# NameError: name 'XGBRegressor' is not defined

# %%
for m in model:
    m.fit(x_train,y_train)
    print('mean_absolute_error of ',m ,'model', mean_absolute_error(y_test,m.predict(x_test)))
    print('mean_square_error of',m,'model' , mean_squared_error(y_test,m.predict(x_test)))
    print('R2 Score of',m,'model', r2_score(y_test,m.predict(x_test) )*100)
    print('X' * 50, '\n\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 for m in model:
#       2     m.fit(x_train,y_train)
#       3     print('mean_absolute_error of ',m ,'model', mean_absolute_error(y_test,m.predict(x_test)))
#
# NameError: name 'model' is not defined

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in model:
    print('Root mean_square of ',i, 'model',np.sqrt(mean_squared_error(y_test,i.predict(x_test))))
    score=cross_val_score(i,X,Y,cv=10, scoring='neg_mean_squared_error').mean()
    print("cross Validation score of root mean square ",i ," is ",np.sqrt(-score))
    print('*'*50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 for i in model:
#       2     print('Root mean_square of ',i, 'model',np.sqrt(mean_squared_error(y_test,i.predict(x_test))))
#       3     score=cross_val_score(i,X,Y,cv=10, scoring='neg_mean_squared_error').mean()
#
# NameError: name 'model' is not defined

# %%
n_estimator= [200, 400, 600, 800, 1000]  # no of tree in Random forest, default is 100
max_features= ['auto','sqrt','log2']  # mini no of features to create Decission Tree
max_depth=[10, 64, 118, 173, 227, 282, 336]  #  Max depth of decision tree
min_samples_split= [1,2,3]   # mini no of sample rerquired to split node
min_samples_leaf= [1,3,4,6,7,9]  #mini no of sample required at each leaf node

param_grid= {'n_estimators': n_estimator,
             'max_features':max_features,
             'max_depth':max_depth,
             'min_samples_split':min_samples_split,
             'min_samples_leaf':min_samples_leaf,
             }
param_grid
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000],
#  'max_features': ['auto', 'sqrt', 'log2'],
#  'max_depth': [10, 64, 118, 173, 227, 282, 336],
#  'min_samples_split': [1, 2, 3],
#  'min_samples_leaf': [1, 3, 4, 6, 7, 9]}

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
grid_search=RandomizedSearchCV(estimator=RFR_model,param_distributions=param_grid,cv=5,n_jobs=-1,verbose=2)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
grid_search.best_estimator_

# %%
grid_search.best_params_

# %%
GCV_pred=grid_search.best_estimator_.predict(x_test)

np.sqrt(mean_squared_error(y_test,GCV_pred))

# %%
import joblib
joblib.dump(grid_search.best_estimator_,"Rainfall_Prediction_in_mm.pkl")
